# %%
import numpy as np, matplotlib.pyplot as plt, random, time
from functools import lru_cache
from pyquil import Program, get_qc
from pyquil.gates import *
import os
from pyquil.quilatom import quil_sin, quil_cos, Parameter
from pyquil.quilbase import DefGate
from pyquil.latex import display, to_latex
# import Peres_helpers as hf
import pickle
from collections import Counter

# Helpers
def dura(func):
	'''
	A wrapper function to calculate the time of any process we want.
	'''
	def wrapper(*args, **kwargs):
		start = time.time()
		print(f'{func.__name__} has started.')
		val = func(*args, **kwargs)
		ty_res = time.gmtime(time.time() - start)
		res = time.strftime("%H:%M:%S",ty_res)
		print(f'{func.__name__} completed in {res}')
		return val
	return wrapper

def params_real():
	'''
	Generates parameters to prepare random REAL quantum states.
	'''
	theta = np.arccos(np.cos(e) - 2 * np.array([random.uniform(0,1) for _ in range(3)]))
	phi = np.array([(np.pi)*random.randint(0,1) for _ in range(3)])
	params = zip(theta, phi)
	return list(params)
def params_complex():
	'''
	Generates parameters to prepare COMPLEX quantum states.
	'''
	theta = np.arccos(np.cos(e) - 2 * np.array([random.uniform(0,1) for _ in range(3)]))
	phi = np.array([2*np.pi*random.uniform(0,1) for _ in range(3)])
	params = zip(theta, phi)
	return list(params)

n_rows = 1
n_cols = 8192
e = 0

# Sigma calculation. This function executes the circuit.
def sigma(params, params_ancilla):
	'''
	Compile and run the circuit given the parameters. The list of outputs is returned.
	'''
	params = list(zip(*params)) # Unpack parameters
	theta, phi = params[0], params[1] # Store thetas and phis in seperate tuples.
	
	bitstrings = qc.run(exe, memory_map={'theta': theta, 'phi': phi, 'th':[params_ancilla]}) # Stores the output of the circuit run.
	return bitstrings

# Gammas for different pairs of states.
def g(u, p):
	'''
	Calls the sigma function with different values of parameters correponding to the configurations, |ψ12>, |ψ1> and |ψ2>. Returns a
	dictionary with configurations as keys and output as values (which are lists).
	'''
	s12 = sigma(u, p) # Circuit for superposition of states.

	p = 0
	s1 = sigma(u, p) # Circuit for state 1.

	p = np.pi
	s2 = sigma(u, p) # Circuit for state 2.

	return {'s12': s12, 's1': s1, 's2': s2}

# Computing all the three gammas.
@dura # To calculate the time taken for all the circuits to run.
def f(u,p):
	'''
	Calls the g function to run the circuit for different configurations and returns a dictionary with 'a', 'b', 'c' as keys and the corresponding 
	outputs of the three configurations. This marks the end of what the Quantum computer must be used for. After this it is all about post-
	processing the data.
	'''
	alpha = g([u[0], u[1]], p[0]) # Running for alpha
	beta = g([u[1], u[2]], p[1]) # Running for beta
	gamma = g([u[2], u[0]], p[2]) # Running for gamma

	res = {'a': alpha, 'b': beta, 'c': gamma}

	return res

# Constructs the parametric circuit for Peres-test.
def circuit(s, a):
    '''
    Construction of the circuit to perform the Peres' test.
    '''
    circ = Program() # Initializing circuit.

    # circ += dg # Adding the definition of custom CRY gate.
    c = circ.declare('ro', 'BIT', 2) # Classical bits to store outcomes.
    theta = circ.declare('theta', 'REAL', 2)
    phi = circ.declare('phi', 'REAL', 2)
    th = circ.declare('th', 'REAL', 1)
    # 	s, a = 0, 1 # Labeling state and ancilla qubits.

    circ += RY(th,a) # Ancilla bit to superposition of give probabilities.

    # Controlled scatters
    circ += X(a)
    circ += CNOT(a,s)
    circ += RY(-theta[0]/2, s)
    circ += CNOT(a,s)
    circ += RY(theta[0]/2, s)
    circ += CPHASE(phi[0],a,s)
    circ += X(a)

    circ += CNOT(a,s)
    circ += RY(-theta[1]/2, s)
    circ += CNOT(a,s)
    circ += RY(theta[1]/2, s)
    circ += CPHASE(phi[1],a,s)

    # Hadamard on the ancilla
    circ += H(a)

    circ += MEASURE(s, c[0])
    circ += MEASURE(a, c[1])

    # 	for i in range(2):
    # 	    circ += MEASURE(i, c[i])

    circ.wrap_in_numshots_loop(n_rows * n_cols) # Run the circuit n_rows*n_cols times to get distribution.
    # print(circ)
    return circ


qc = get_qc('Aspen-9', as_qvm=True) # Initialise QPU.

circ = circuit(4, 5)
exe = qc.compile(circ)

for i in range(1):
    # State parameters.
    u = params_complex() # Parameters for three random states is chosen. For real states, call "params_real()".
    # u = params_real() # Parameters for three random states is chosen. For real states, call "params_real()".
    p = np.array([random.uniform(0,np.pi) for _ in range(3)]) # The coefficients of superposition is chosen.


    print('Running the circuit.')
    res = f(u,p) 
    filename = f'peres_from_Rigetti_Aspen_9_run_{i}.pkl'
    with open(filename, 'wb') as file:
    pickle.dump((u,p,res), file)
# Out:
# Running the circuit.
# f has started.
# f completed in 00:00:07

# %%
for x in qc.device.get_isa().edges:
    print(x, end='\n\n')
# Out:
# Edge(targets=(0, 1), type=None, dead=False, gates=[GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.01), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8446696871831343)])
#
# Edge(targets=(0, 7), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9533392824925881), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9410160779394914), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9607105616193717)])
#
# Edge(targets=(1, 2), type=None, dead=True, gates=[GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=None)])
#
# Edge(targets=(1, 16), type=None, dead=False, gates=[GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8402641762686417)])
#
# Edge(targets=(2, 3), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.7829547742639393), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.7905075436774532), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.838736942401193)])
#
# Edge(targets=(2, 15), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.934188030326501), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8653819956055334), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.881012530457828)])
#
# Edge(targets=(3, 4), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.8337562075477772), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8334785029557206), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.7509880300192193)])
#
# Edge(targets=(4, 5), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9853295150051185), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9865805466742504), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9761165728006891)])
#
# Edge(targets=(5, 6), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.8539492026550987), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.86001235259562), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8044619208026443)])
#
# Edge(targets=(6, 7), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.8274401737628536), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8357316044832114), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8078429887573396)])
#
# Edge(targets=(10, 11), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9916914330689366), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9791939619082638), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9869782872683891)])
#
# Edge(targets=(10, 17), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.979683135403277), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9699139351420136), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9655038894812322)])
#
# Edge(targets=(11, 12), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.945660658224632), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9547286192328934), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9413878535442103)])
#
# Edge(targets=(11, 26), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.849985101147121), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8326771183754991)])
#
# Edge(targets=(12, 13), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9835524865495457), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.97898529608061), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9897150737938764)])
#
# Edge(targets=(12, 25), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9771324643627608), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9570653742771594)])
#
# Edge(targets=(13, 14), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.8910124795038367), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9424779136027981), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9571816013882016)])
#
# Edge(targets=(14, 15), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.8226408476015927), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9020618437196317), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.7853855029870254)])
#
# Edge(targets=(15, 16), type=None, dead=True, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=None), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=None), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=None)])
#
# Edge(targets=(16, 17), type=None, dead=False, gates=[GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9275664037858007)])
#
# Edge(targets=(20, 21), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9476393221486393), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8980151081441402), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.899810492303985)])
#
# Edge(targets=(20, 27), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9469015925406318), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9066864740659585), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9531880057694679)])
#
# Edge(targets=(21, 36), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9726862097858827), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9589194913467183), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.986571926886583)])
#
# Edge(targets=(23, 24), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9232005411487191), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9229663459243563), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9730505549646054)])
#
# Edge(targets=(24, 25), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9479514907335084), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9582503867957667), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9660032108510848)])
#
# Edge(targets=(25, 26), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9421210675710592), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8101290510953806), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8357764447699157)])
#
# Edge(targets=(26, 27), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.8368361394433941), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8096972828658635), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8378722135480108)])
#
# Edge(targets=(30, 31), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.949953949252384), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8044188166148946), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.6675152197129147)])
#
# Edge(targets=(30, 37), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9712115453846479), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8044793236903459), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.8917053144416982)])
#
# Edge(targets=(31, 32), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9755492860031799), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9702866471414282), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9853361211092458)])
#
# Edge(targets=(32, 33), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9667863083963063), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9241334125901483), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9655031389075698)])
#
# Edge(targets=(33, 34), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.960459190577131), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9116108073630326), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9525583874546192)])
#
# Edge(targets=(34, 35), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9658763641205763), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9484945039399547), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9771875512395386)])
#
# Edge(targets=(35, 36), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.986466036379364), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9809737742732599), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9892699104227859)])
#
# Edge(targets=(36, 37), type=None, dead=False, gates=[GateInfo(operator='CZ', parameters=[], arguments=['_', '_'], duration=200, fidelity=0.9074478770196421), GateInfo(operator='CPHASE', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9466005522621014), GateInfo(operator='XY', parameters=['theta'], arguments=['_', '_'], duration=200, fidelity=0.9609988267787773)])
